# %%
import src

# Automatically reload modules (so that it reloads when you edit the code)
# %load_ext autoreload 
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# Example 1: Circumpolar target: Polaris 

Observer = src.get_observer(observatory_name="Winer") 
Target = src.get_target(target_name="Polaris")
dates, times, target_alt, sun_alt = src.calc_visibility(Observer, Target)
src.plot_visibility(dates, times, target_alt, sun_alt, Target, Observer)
# Out:
# Calculating visibility...
# Target: Polaris (02:31:49.1 +89°15'50.8")
# Observer: Winer (31.67° N, 110.60° W)
# Number of years: 2
# Minutes between each data point (resolution): 10
# Calculating target altitudes...
# Calculating Sun altitudes...
# Done.

# %%
# Example 2: Nearly circumpolar target: Epsilon Ursae Minoris (dec = 82 degrees)

Observer = src.get_observer(observatory_name="Winer") 
Target = src.get_target(target_name="Epsilon Ursae Minoris")
dates, times, target_alt, sun_alt = src.calc_visibility(Observer, Target)
src.plot_visibility(dates, times, target_alt, sun_alt, Target, Observer)
# Out:
# Calculating visibility...
# Target: Epsilon Ursae Minoris (16:45:58.2 +82°02'14.1")
# Observer: Winer (31.67° N, 110.60° W)
# Number of years: 2
# Minutes between each data point (resolution): 10
# Calculating target altitudes...
# Calculating Sun altitudes...
# Done.

# %%
# Example 3: Barely visible target: Fomalhaut (dec = -30 degrees)

Observer = src.get_observer(observatory_name="Winer") 
Target = src.get_target(target_name="Fomalhaut")
dates, times, target_alt, sun_alt = src.calc_visibility(Observer, Target)
src.plot_visibility(dates, times, target_alt, sun_alt, Target, Observer) 

# Show how the plot changes if you allow lower altitudes to count as obsevable 
src.plot_visibility(dates, times, target_alt, sun_alt, Target, Observer, target_min_alt=5)
# Out:
# Calculating visibility...
# Target: Fomalhaut (22:57:39.0 -29°37'20.1")
# Observer: Winer (31.67° N, 110.60° W)
# Number of years: 2
# Minutes between each data point (resolution): 10
# Calculating target altitudes...
# Calculating Sun altitudes...
# Done.

# %%
# Example 4: Summer star: Altair 

Observer = src.get_observer(observatory_name="Winer") 
Target = src.get_target(target_name="Altair")
dates, times, target_alt, sun_alt = src.calc_visibility(Observer, Target)
src.plot_visibility(dates, times, target_alt, sun_alt, Target, Observer)
# Out:
# Calculating visibility...
# Target: Altair (19:50:47.0 +08°52'06.0")
# Observer: Winer (31.67° N, 110.60° W)
# Number of years: 2
# Minutes between each data point (resolution): 10
# Calculating target altitudes...
# Calculating Sun altitudes...
# Done.

# %%
# Example 5: Winter star: Betelgeuse 

Observer = src.get_observer(observatory_name="Winer") 
Target = src.get_target(target_name="Betelgeuse")
dates, times, target_alt, sun_alt = src.calc_visibility(Observer, Target)
src.plot_visibility(dates, times, target_alt, sun_alt, Target, Observer) 

# Why did we increase the number of years to 2? This is what happens if you don't: 
dates, times, target_alt, sun_alt = src.calc_visibility(Observer, Target, num_yrs=1)
src.plot_visibility(dates, times, target_alt, sun_alt, Target, Observer)
# Out:
# Calculating visibility...
# Target: Betelgeuse (05:55:10.3 +07°24'25.4")
# Observer: Winer (31.67° N, 110.60° W)
# Number of years: 2
# Minutes between each data point (resolution): 10
# Calculating target altitudes...
# Calculating Sun altitudes...
# Done.
#
# Calculating visibility...
# Target: Betelgeuse (05:55:10.3 +07°24'25.4")
# Observer: Winer (31.67° N, 110.60° W)
# Number of years: 1
# Minutes between each data point (resolution): 10
# Calculating target altitudes...
# Calculating Sun altitudes...
# Done.

# %%
# Example 6: Altair, but seen from farther north 

Observer = src.get_observer(lat_long_tuple=(55, -100)) 
Target = src.get_target(target_name="Altair")
dates, times, target_alt, sun_alt = src.calc_visibility(Observer, Target)

src.plot_visibility(dates, times, target_alt, sun_alt, Target, Observer) 

# Show what happens if you require a stricter darkness level 
src.plot_visibility(dates, times, target_alt, sun_alt, Target, Observer, sun_max_alt=-18)

# %%
# Example 7: Same star, but seen from the southern hemisphere 

Observer = src.get_observer(lat_long_tuple=(-10, -100)) 
Target = src.get_target(target_name="Altair")
dates, times, target_alt, sun_alt = src.calc_visibility(Observer, Target)
src.plot_visibility(dates, times, target_alt, sun_alt, Target, Observer)
# Out:
# Calculating visibility...
# Target: Altair (19:50:47.0 +08°52'06.0")
# Observer: None (10.00° S, 100.00° W)
# Number of years: 2
# Minutes between each data point (resolution): 10
# Calculating target altitudes...
# Calculating Sun altitudes...
# Done.

# %%
# Try to observe a summer star from the far north while requiring full night: impossible 

Observer = src.get_observer(lat_long_tuple=(55, -100)) 
Target = src.get_target(target_radec_str="17 50 47 +8 52 06")
dates, times, target_alt, sun_alt = src.calc_visibility(Observer, Target)
src.plot_visibility(dates, times, target_alt, sun_alt, Target, Observer, sun_max_alt=-18)
# Out:
# Calculating visibility...
# Target: None (17:50:47.0 +08°52'06.0")
# Observer: None (55.00° N, 100.00° W)
# Number of years: 2
# Minutes between each data point (resolution): 10
# Calculating target altitudes...
# Calculating Sun altitudes...
# Done.

# %%
# What about a winter star? Easy (changing the RA has a huge effect when you're far north)

Observer = src.get_observer(lat_long_tuple=(55, -100)) 
Target = src.get_target(target_radec_str="5 50 47 +8 52 06")
dates, times, target_alt, sun_alt = src.calc_visibility(Observer, Target)
src.plot_visibility(dates, times, target_alt, sun_alt, Target, Observer, sun_max_alt=-18)
# Out:
# Calculating visibility...
# Target: None (05:50:47.0 +08°52'06.0")
# Observer: None (55.00° N, 100.00° W)
# Number of years: 2
# Minutes between each data point (resolution): 10
# Calculating target altitudes...
# WARNING: Tried to get polar motions for times after IERS data is valid. Defaulting to polar motion from the 50-yr mean for those. This may affect precision at the arcsec level. Please check your astropy.utils.iers.conf.iers_auto_url and point it to a newer version if necessary. [astropy.coordinates.builtin_frames.utils]
# Calculating Sun altitudes...
# Done.

# %%
# Okay I just wanted to see what would happen if we went REALLY far north 

Observer = src.get_observer(lat_long_tuple=(70, -100)) 
Target = src.get_target(target_radec_str="5 50 47 +8 52 06")
dates, times, target_alt, sun_alt = src.calc_visibility(Observer, Target)
src.plot_visibility(dates, times, target_alt, sun_alt, Target, Observer, sun_max_alt=-18)
# Out:
# Calculating visibility...
# Target: None (05:50:47.0 +08°52'06.0")
# Observer: None (70.00° N, 100.00° W)
# Number of years: 2
# Minutes between each data point (resolution): 10
# Calculating target altitudes...
# Calculating Sun altitudes...
# Done.
