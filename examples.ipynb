# %%
import src

# Automatically reload modules (so that it reloads when you edit the code)
# %load_ext autoreload 
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# Example 1: Circumpolar target: Polaris 

observer = src.get_observer(observatory_name="Winer") 
target = src.get_target(target_name="Polaris", num_days=365)

datetimes_utc_1d, target_alt_1d, sun_alt_1d = src.calc_visibility(observer, target) 

x_dates, y_times, sun_alt_2d = src.reshape_altitude(observer, datetimes_utc_1d, sun_alt_1d)
x_dates, y_times, target_alt_2d = src.reshape_altitude(observer, datetimes_utc_1d, target_alt_1d)
fig = src.plot_visibility(x_dates, y_times, target_alt_2d, sun_alt_2d, target, observer)
# Out:
# Looking up 'Polaris' in Simbad...
# Retrieved 'Polaris' from Simbad
# Interpolating RA/dec onto 60min grid
# Calculating altaz_frame
# Calculating target altitudes on 60min grid
# Interpolating target altitudes onto 5min grid
# Calculating Sun altitudes on 60min grid
# Interpolating Sun altitudes onto 5min grid

# %%
# Example 2: Nearly circumpolar target: Epsilon Ursae Minoris (dec = 82 degrees)

observer = src.get_observer(observatory_name="Winer") 
target = src.get_target(target_name="Epsilon Ursae Minoris")

datetimes_utc_1d, target_alt_1d, sun_alt_1d = src.calc_visibility(observer, target) 

x_dates, y_times, sun_alt_2d = src.reshape_altitude(observer, datetimes_utc_1d, sun_alt_1d)
x_dates, y_times, target_alt_2d = src.reshape_altitude(observer, datetimes_utc_1d, target_alt_1d)
fig = src.plot_visibility(x_dates, y_times, target_alt_2d, sun_alt_2d, target, observer)
# Out:
# Looking up 'Epsilon Ursae Minoris' in Simbad...
# Retrieved 'Epsilon Ursae Minoris' from Simbad
# Interpolating RA/dec onto 60min grid
# Calculating altaz_frame
# Calculating target altitudes on 60min grid
# Interpolating target altitudes onto 5min grid
# Calculating Sun altitudes on 60min grid
# Interpolating Sun altitudes onto 5min grid

# %%
# Example 3: Barely visible target: Fomalhaut (dec = -30 degrees)

observer = src.get_observer(observatory_name="Winer") 
target = src.get_target(target_name="Fomalhaut")

datetimes_utc_1d, target_alt_1d, sun_alt_1d = src.calc_visibility(observer, target) 

x_dates, y_times, sun_alt_2d = src.reshape_altitude(observer, datetimes_utc_1d, sun_alt_1d)
x_dates, y_times, target_alt_2d = src.reshape_altitude(observer, datetimes_utc_1d, target_alt_1d)

fig = src.plot_visibility(x_dates, y_times, target_alt_2d, sun_alt_2d, target, observer) 

# Show how the plot changes if you allow lower altitudes to count as observable 
fig = src.plot_visibility(x_dates, y_times, target_alt_2d, sun_alt_2d, target, observer, target_min_alt=15)
# Out:
# Looking up 'Fomalhaut' in Simbad...
# Retrieved 'Fomalhaut' from Simbad
# Interpolating RA/dec onto 60min grid
# Calculating altaz_frame
# Calculating target altitudes on 60min grid
# Interpolating target altitudes onto 5min grid
# Calculating Sun altitudes on 60min grid
# Interpolating Sun altitudes onto 5min grid

# %%
# Example 4: Summer star: Altair 

observer = src.get_observer(observatory_name="Winer") 
target = src.get_target(target_name="Altair")

datetimes_utc_1d, target_alt_1d, sun_alt_1d = src.calc_visibility(observer, target) 

x_dates, y_times, sun_alt_2d = src.reshape_altitude(observer, datetimes_utc_1d, sun_alt_1d)
x_dates, y_times, target_alt_2d = src.reshape_altitude(observer, datetimes_utc_1d, target_alt_1d)

fig = src.plot_visibility(x_dates, y_times, target_alt_2d, sun_alt_2d, target, observer)
# Out:
# Looking up 'Altair' in Simbad...
# Retrieved 'Altair' from Simbad
# Interpolating RA/dec onto 60min grid
# Calculating altaz_frame
# Calculating target altitudes on 60min grid
# Interpolating target altitudes onto 5min grid
# Calculating Sun altitudes on 60min grid
# Interpolating Sun altitudes onto 5min grid

# %%
# Example 5: Winter star: Betelgeuse 

observer = src.get_observer(observatory_name="Winer") 
target = src.get_target(target_name="Betelgeuse")

datetimes_utc_1d, target_alt_1d, sun_alt_1d = src.calc_visibility(observer, target) 

x_dates, y_times, sun_alt_2d = src.reshape_altitude(observer, datetimes_utc_1d, sun_alt_1d)
x_dates, y_times, target_alt_2d = src.reshape_altitude(observer, datetimes_utc_1d, target_alt_1d)

fig = src.plot_visibility(x_dates, y_times, target_alt_2d, sun_alt_2d, target, observer)
# Out:
# Looking up 'Betelgeuse' in Simbad...
# Retrieved 'Betelgeuse' from Simbad
# Interpolating RA/dec onto 60min grid
# Calculating altaz_frame
# Calculating target altitudes on 60min grid
# Interpolating target altitudes onto 5min grid
# Calculating Sun altitudes on 60min grid
# Interpolating Sun altitudes onto 5min grid

# %%
# Example 6: Betelgeuse, but seen from Iowa City 

observer = src.get_observer(lat_long_tuple=(41.66, -91.53)) # Iowa City  
target = src.get_target(target_name="Betelgeuse")

datetimes_utc_1d, target_alt_1d, sun_alt_1d = src.calc_visibility(observer, target) 

x_dates, y_times, sun_alt_2d = src.reshape_altitude(observer, datetimes_utc_1d, sun_alt_1d)
x_dates, y_times, target_alt_2d = src.reshape_altitude(observer, datetimes_utc_1d, target_alt_1d)

fig = src.plot_visibility(x_dates, y_times, target_alt_2d, sun_alt_2d, target, observer)
# Out:
# Looking up 'Betelgeuse' in Simbad...
# Retrieved 'Betelgeuse' from Simbad
# Interpolating RA/dec onto 60min grid
# Calculating altaz_frame
# Calculating target altitudes on 60min grid
# WARNING: Tried to get polar motions for times after IERS data is valid. Defaulting to polar motion from the 50-yr mean for those. This may affect precision at the arcsec level. Please check your astropy.utils.iers.conf.iers_auto_url and point it to a newer version if necessary. [astropy.coordinates.builtin_frames.utils]
# Interpolating target altitudes onto 5min grid
# Calculating Sun altitudes on 60min grid
# Interpolating Sun altitudes onto 5min grid

# %%
# Example 7: Use RA/dec string to set target, and set observer location very far north 

observer = src.get_observer(lat_long_tuple=(75, -100)) 
target = src.get_target(target_radec_str="5 50 47 +20 52 06")

datetimes_utc_1d, target_alt_1d, sun_alt_1d = src.calc_visibility(observer, target) 

x_dates, y_times, sun_alt_2d = src.reshape_altitude(observer, datetimes_utc_1d, sun_alt_1d)
x_dates, y_times, target_alt_2d = src.reshape_altitude(observer, datetimes_utc_1d, target_alt_1d)

fig = src.plot_visibility(x_dates, y_times, target_alt_2d, sun_alt_2d, target, observer)
# Out:
# Used target_radec_str = 5 50 47 +20 52 06 to generate target coordinates
# Interpolating RA/dec onto 60min grid
# Calculating altaz_frame
# Calculating target altitudes on 60min grid
# Interpolating target altitudes onto 5min grid
# Calculating Sun altitudes on 60min grid
# Interpolating Sun altitudes onto 5min grid

# %%
# Example 8: Moving target: Mercury 

observer = src.get_observer(lat_long_tuple=(41.66, -91.53)) # Iowa City  
target = src.get_target(target_name=199) # Mercury's ID according to JPL Horizons 

datetimes_utc_1d, target_alt_1d, sun_alt_1d = src.calc_visibility(observer, target) 

x_dates, y_times, sun_alt_2d = src.reshape_altitude(observer, datetimes_utc_1d, sun_alt_1d)
x_dates, y_times, target_alt_2d = src.reshape_altitude(observer, datetimes_utc_1d, target_alt_1d)

# Adjusted visibility constraints because Mercury is hard enough to see 
fig = src.plot_visibility(x_dates, y_times, target_alt_2d, sun_alt_2d, target, observer, target_min_alt=0, sun_max_alt=0)
# Out:
# Looking up '199' in Simbad...
# Simbad lookup failed ('int' object has no attribute 'replace'), trying JPL Horizons...
# Retrieved '199' from JPL Horizons
# RA/dec calculated with cadence of 1D
# Interpolating RA/dec onto 60min grid
# Calculating altaz_frame
# Calculating target altitudes on 60min grid
# WARNING: Tried to get polar motions for times after IERS data is valid. Defaulting to polar motion from the 50-yr mean for those. This may affect precision at the arcsec level. Please check your astropy.utils.iers.conf.iers_auto_url and point it to a newer version if necessary. [astropy.coordinates.builtin_frames.utils]
# Interpolating target altitudes onto 5min grid
# Calculating Sun altitudes on 60min grid
# Interpolating Sun altitudes onto 5min grid

# %%
# Moving target: The asteroid Ceres

observer = src.get_observer(lat_long_tuple=(41.66, -91.53)) # Iowa City  
target = src.get_target(target_name="Ceres") 

datetimes_utc_1d, target_alt_1d, sun_alt_1d = src.calc_visibility(observer, target) 

x_dates, y_times, sun_alt_2d = src.reshape_altitude(observer, datetimes_utc_1d, sun_alt_1d)
x_dates, y_times, target_alt_2d = src.reshape_altitude(observer, datetimes_utc_1d, target_alt_1d)

fig = src.plot_visibility(x_dates, y_times, target_alt_2d, sun_alt_2d, target, observer)
# Out:
# Looking up 'Ceres' in Simbad...
# WARNING: NoResultsWarning: The request executed correctly, but there was no data corresponding to these criteria in SIMBAD [astroquery.simbad.core]
# Simbad lookup failed (index 0 is out of bounds for axis 0 with size 0), trying JPL Horizons...
# Retrieved 'Ceres' from JPL Horizons
# RA/dec calculated with cadence of 1D
# Interpolating RA/dec onto 60min grid
# Calculating altaz_frame
# Calculating target altitudes on 60min grid
# WARNING: Tried to get polar motions for times after IERS data is valid. Defaulting to polar motion from the 50-yr mean for those. This may affect precision at the arcsec level. Please check your astropy.utils.iers.conf.iers_auto_url and point it to a newer version if necessary. [astropy.coordinates.builtin_frames.utils]
# Interpolating target altitudes onto 5min grid
# Calculating Sun altitudes on 60min grid
# Interpolating Sun altitudes onto 5min grid

# %%
# Moving target: Mars 

observer = src.get_observer(lat_long_tuple=(41.66, -91.53)) # Iowa City  
target = src.get_target(target_name=499) # Mars, according to JPL Horizons 

datetimes_utc_1d, target_alt_1d, sun_alt_1d = src.calc_visibility(observer, target) 

x_dates, y_times, sun_alt_2d = src.reshape_altitude(observer, datetimes_utc_1d, sun_alt_1d)
x_dates, y_times, target_alt_2d = src.reshape_altitude(observer, datetimes_utc_1d, target_alt_1d)

fig = src.plot_visibility(x_dates, y_times, target_alt_2d, sun_alt_2d, target, observer)
# Out:
# Looking up '499' in Simbad...
# Simbad lookup failed ('int' object has no attribute 'replace'), trying JPL Horizons...
# Retrieved '499' from JPL Horizons
# RA/dec calculated with cadence of 1D
# Interpolating RA/dec onto 60min grid
# Calculating altaz_frame
# Calculating target altitudes on 60min grid
# WARNING: Tried to get polar motions for times after IERS data is valid. Defaulting to polar motion from the 50-yr mean for those. This may affect precision at the arcsec level. Please check your astropy.utils.iers.conf.iers_auto_url and point it to a newer version if necessary. [astropy.coordinates.builtin_frames.utils]
# Interpolating target altitudes onto 5min grid
# Calculating Sun altitudes on 60min grid
# Interpolating Sun altitudes onto 5min grid

# %%
# Near earth asteroid 
# On August 18, 2002, this asteroid passed very close to earth 
# Since it was moving so fast, we need to sample the RA/dec more often than once per day 

observer = src.get_observer(lat_long_tuple=(41.66, -91.53)) # Iowa City  

target = src.get_target(target_name="2002 NY40", num_days=60, start_str='2002-07-18 12:00:00', freq_calc_radec="120min")

datetimes_utc_1d, target_alt_1d, sun_alt_1d = src.calc_visibility(observer, target, freq_calc_altaz="1min", freq_interp_altaz="1min") 

x_dates, y_times, sun_alt_2d = src.reshape_altitude(observer, datetimes_utc_1d, sun_alt_1d)
x_dates, y_times, target_alt_2d = src.reshape_altitude(observer, datetimes_utc_1d, target_alt_1d)

fig = src.plot_visibility(x_dates, y_times, target_alt_2d, sun_alt_2d, target, observer)
# Out:
# Looking up '2002 NY40' in Simbad...
# WARNING: NoResultsWarning: The request executed correctly, but there was no data corresponding to these criteria in SIMBAD [astroquery.simbad.core]
# Simbad lookup failed (index 0 is out of bounds for axis 0 with size 0), trying JPL Horizons...
# Retrieved '2002 NY40' from JPL Horizons
# RA/dec calculated with cadence of 120min
# Interpolating RA/dec onto 1min grid
# Calculating altaz_frame
# Calculating target altitudes on 1min grid
# Interpolating target altitudes onto 1min grid
# Calculating Sun altitudes on 1min grid
# Interpolating Sun altitudes onto 1min grid
